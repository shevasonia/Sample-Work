# %% [markdown]
# # Supervised Learning
# ## Machine learning (ML)
#
# The sentiment analysis program we wrote earlier (in Lab 3) adopts a non-machine learning algorithm. That is, it tries to define what words have good and bad sentiments and assumes all the necessary words of good and bad sentiments exist in the word_sentiment.csv file.
#
#
# Machine Learning (ML) is a class of algorithms, which are data-driven, i.e. unlike "normal" algorithms, it is the data that "tells" what the "good answer" is. A machine learning algorithm would not have such coded definition of what a good and bad sentiment is, but would "learn-by-examples". That is, you will show several sentences which have been labeled as good sentiment and bad sentiment and a good ML algorithm will eventually learn and be able to predict whether or not an unseen sentence has a good or bad sentiment. This particular example of sentiment analysis is "supervised", which means that your example words must be labeled, or explicitly say which sentences are good and which are bad.
#
# On the other hand, in the case of unsupervised learning, the sentence examples are not labeled. Of course, in such a case the algorithm itself cannot "invent" what a good sentiment is, but it can try to cluster the data into different groups, e.g. it can figure out that sentences that have certain  words are different from those hat have others (eg. it might cluster sentecences around words like mother,childeren etc. and find that cluster to be different from another group of sentences that contain words like politician).
# There are "intermediate" forms of supervision, i.e. semi-supervised and active learning. Technically, these are supervised methods in which there is some "smart" way to avoid a large number of labeled examples.
#
# - In active learning, the algorithm itself decides which thing you should label (e.g. it can be pretty sure about a sentence that has the word fantastic, but it might ask you to confirm if the sentence may have a negative like “not”).
# - In semi-supervised learning, there are two different algorithms, which start with the labeled examples, and then "tell" each other the way they think about some large number of unlabeled data. From this "discussion" they learn.
#
#
# #### Figure 1: Supervised learning approach
#
#
# <center>
#     <img src="ML_SL.png"  width="500" title="Supervised learning">
# </center>
#
# Ref 1:
# https://www.youtube.com/watch?v=nKW8Ndu7Mjw&t=382s
#
# Ref 2:
# https://www.nltk.org/book/ch06.html

# %% [markdown]
# ## Sentiment Excercise:
#
# In this excercise we try to improve the *word_sentiment.csv* file. We build a classifier model to predict the sentiment of an unknown word, using the the dictionary (corpus) of sentiments available in the word_sentiment.csv file.

# %% [markdown]
# ### Training the ML algorithm
#
# #### Module : NLTK (Natural Language Tool Kit)
# NLTK module is built for working with language data.  NLTK supports classification, tokenization, stemming, tagging, parsing, and semantic reasoning functionalities. We will use the NLTK module and employ the Naive Bayes method to classify words as being either positive or negative sentiment. You can also use other modules specifically meant for ML eg. sklearn module.
#
# The nltk module may not be included in your laptop. In case it is not installed you need to :
#
# *pip install --user nltk*
#
# To check if it is insatlled just run
#
# *import nltk*

# %%
pip install --user nltk
# Out:
# Requirement already satisfied: nltk in ./opt/anaconda3/lib/python3.9/site-packages (3.7)
# Requirement already satisfied: tqdm in ./opt/anaconda3/lib/python3.9/site-packages (from nltk) (4.64.1)
# Requirement already satisfied: click in ./opt/anaconda3/lib/python3.9/site-packages (from nltk) (8.0.4)
# Requirement already satisfied: joblib in ./opt/anaconda3/lib/python3.9/site-packages (from nltk) (1.1.0)
# Requirement already satisfied: regex>=2021.8.3 in ./opt/anaconda3/lib/python3.9/site-packages (from nltk) (2022.7.9)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Step 1: Feature extraction
# Define what features of a word that you want to use in order to classify the data set. We will select two features the first and the last letter of the word.
#
# **Tokenization:**  tokenization is the task of chopping text up into pieces (e.g. words or letter / character), called tokens
# * For words, the letters in the word can act as tokens
#
# **Feature generation:** selecting the right features and determining how to encode them
#
# * Feature 1: First letter of the word
# * Feature 2: Last letter of the word
#
# #### Figure 2: Feature Extractor
#
#
# <center>
#     <img src="FE2.png"  width="500" title="Feature Extraction">
# </center>

# %% [markdown]
# #### Part 1: Feature Extractor

# %%
def feature_extractor(word):
    """ This is the feature extractor. Givern a word, it returns a dictonary of the first and last letter
    of the word given to it"""
    first_l = word[0]
    last_l = word[-1]
    dict_feature = {"first letter" : first_l,"last letter" : last_l}
    return dict_feature

input_word = input("Enter a word ").lower()
feature = feature_extractor(input_word)
print(feature)
# Out:
# Enter a word sheva
# {'first letter': 's', 'last letter': 'a'}

# %% [markdown]
# #### Part 2: Create the feature set
# We will use the corpus of sentiments from the word_sentiment.csv file to create a feature dataset which we will use to train and test the ML model.

# %%
import csv

def feature_extractor(word):
    """ This is my feature extractor. Givern a word, it returns a dictonary of the first and last letter
    of the word given to it"""
    first_l = word[0]
    last_l = word[-1]
    dict_feature = {"first letter" : first_l,"last letter" : last_l}
    return dict_feature



def gen_featureset():
    """ This function creates a feature set for all the words i nthe the word_sentiment.csv file"""
    SENTIMENT_CSV=r"/Users/sheva/Downloads/TweetSentiment (1).csv"
    with open(SENTIMENT_CSV,'rt', encoding='utf-8') as csvobj:
        ws_data = csv.reader(csvobj)
        featureset = list()
        for row in ws_data:
            w_feature = list()
            feature = feature_extractor(row[0]) #extract the features
            w_feature.append(feature)
            w_feature.append(row[1]) #append the sentiment for each word feature
            featureset.append(w_feature)
            print(w_feature)
        return featureset
            
featureset = gen_featureset()
# Out:
# [{'first letter': 'n', 'last letter': 'e'}, 'On our balcony overlooking the beach...only 3 more nights of this! ']
# [{'first letter': 'p', 'last letter': 'e'}, 'I am not fuctioning this morning. Thanks to my work wife @niki_cole for my venti dirty chai with an extra shot. She loves me ']
# [{'first letter': 'n', 'last letter': 'e'}, "Can't beat all time low.. (: I soooooo want to go to Metro Station..  Your cheap shots wont be able to break bones"]
# [{'first letter': 'p', 'last letter': 'e'}, '@faiththedog thanks for coming out and visiting us in texas. the message was fun and inspirational ']
# [{'first letter': 'n', 'last letter': 'e'}, '@ablegamers Keep your chin up, man! Stay strong! ']
# [{'first letter': 'n', 'last letter': 'e'}, "In Spanish with @TheSuperSuus  I'm bored"]
# [{'first letter': 'n', 'last letter': 'e'}, "Reluctantly going to sleep - don't want to be any closer to waking up to another rainy week ahead "]
# [{'first letter': 'p', 'last letter': 'e'}, 'woken up happy  look at the sun!!!']
# [{'first letter': 'n', 'last letter': 'e'}, "Met an editor from Event News where I used to work. Really wish I could go back, but their paychecks can't pay the bills. "]
# [{'first letter': 'p', 'last letter': 'e'}, 'Another water fight haha im freakin lovin this weather ']
# [{'first letter': 'n', 'last letter': 'e'}, '@brokenleg U havent seen me, talked to me, i hit u up and u dnt answer back but u talk to every1 else ']
# [{'first letter': 'n', 'last letter': 'e'}, "@vinny_vegas I'm home visiting my family now, but my trip only overlaps yours by 1 day  Gotta make it count!"]
# [{'first letter': 'p', 'last letter': 'e'}, '!@BuzzEdition Hey there Busy bee, how goes it?  I think I missed lots what happened 2 @Jason_Pollock?! and why he is such an asset..']
# [{'first letter': 'n', 'last letter': 'e'}, "@iJessie That's the thing - i can't.  I've held it back for so long, I can't do it. "]
# [{'first letter': 'n', 'last letter': 'e'}, "Can't get in contact with his family in Tehran. "]
# [{'first letter': 'n', 'last letter': 'e'}, 'Sitting in englishh ... Boredomm    I hatee English, that soundsbad ... i hate the subject .. i got a B haha .....o_O']
# [{'first letter': 'p', 'last letter': 'e'}, 'Rise and shine beautiful, time for another wonderful day of your life! ']
# [{'first letter': 'n', 'last letter': 'e'}, '@lo_blomlie i wish i couuuuld  urghhh.!!!']
# [{'first letter': 'n', 'last letter': 'e'}, "Watching UP and it's sad how my parents, brother and i finished all the food and its only the previews right now "]
# [{'first letter': 'p', 'last letter': 'e'}, '@don_iain Maybe one day we will get there ... ']
# [{'first letter': 'n', 'last letter': 'e'}, 'I missed 90210 AGAIN ']
# [{'first letter': 'n', 'last letter': 'e'}, '@promotingyou @CristalBubblin lol  It was a joke but Twitter was slow with the execution of my joke. ']
# [{'first letter': 'n', 'last letter': 'e'}, 'mymaths time....if only i cud read the mind of a nerd durin the exam ']
# [{'first letter': 'n', 'last letter': 'e'}, "@BDOTSTRONG my cell phone? What the heck can I do on here except Twitter  when I'm sad &quot;internet window shopping&quot; soothes me. Lol"]
# [{'first letter': 'p', 'last letter': 'e'}, '@MeldyCo thanks for following ']
# [{'first letter': 'p', 'last letter': 'e'}, 'listening to @Jonasbrothers new album!!  &lt;3 i LOVE it already!! cant wait to see them in concert on the 22nd of november in manchester!!']
# [{'first letter': 'n', 'last letter': 'e'}, "Just spoke to T. Sounds very flat and doesn't want to talk at all. Told me to mind my own business when I asked how he is "]
# [{'first letter': 'p', 'last letter': 'e'}, 'On the way to the rangers game ']
# [{'first letter': 'n', 'last letter': 'e'}, 'Woot! Twins game is on @ 3pm today! Yay! It looks like rain today  UGH oh well its still gonna be an awesome day!']
# [{'first letter': 'n', 'last letter': 'e'}, '@ObviouslyBrown I forgot to order the chicken joy  FAIL!']
# [{'first letter': 'n', 'last letter': 'e'}, 'soooooooo sleepy...got out of work today  but i have to spend the day doing homework  I want to take a nap .Anywhoo.... 11 MORE DAYS!!!!']
# [{'first letter': 'p', 'last letter': 'e'}, "@walkingpainting nice, can't wait. "]
# [{'first letter': 'p', 'last letter': 'e'}, 'Pizza, chocolate and Mystery Men. A good night!  Quote: &quot;You must lash out with every limb, like the octopus who plays the drums.&quot;']
# [{'first letter': 'p', 'last letter': 'e'}, '@johncrief Delayed response, I know, but writing is going well. Lots to say.  You should hit up an open mic with us sometime soon and jam!']
# [{'first letter': 'p', 'last letter': 'e'}, 'nobody will admit to voting BNP  that makes me laugh.']
# [{'first letter': 'p', 'last letter': 'e'}, "thinks it's funny that the old way of reading the newspaper in the morning has been replaced by digg, twitter and Facebook "]
# [{'first letter': 'p', 'last letter': 'e'}, 'Ok time to go sleep, its been an eventful day! Thank you @donniewahlberg @jordanknight and @joeymcintyre  Goodnight all!']
# [{'first letter': 'n', 'last letter': 'e'}, '@mkayes I know just fed up with coughing esp at night sound like I am a smoker and Im not!!Chest really sore been in bed most of week ']
# [{'first letter': 'n', 'last letter': 'e'}, "Going back to work 2moro after a week off. Not looking forward to it  know it's going to be the usual crap."]
# [{'first letter': 'p', 'last letter': 'e'}, 'About to start packing for my trip to Rome with mum. I would rather be outside tanning, but shall settle for a facial at Heathrow ']
# [{'first letter': 'n', 'last letter': 'e'}, '@Jess0302  Miami is doing ok I guess. Nothing new.... ']
# [{'first letter': 'p', 'last letter': 'e'}, '@mshairi  Hahahaha You are very welcome...who knows I might even convert you into a rugby lover ']
# [{'first letter': 'p', 'last letter': 'e'}, '2009 Colorado Rush tournament champions right here!! ']
# [{'first letter': 'n', 'last letter': 'e'}, 'wow the battery on my nokia has basically died... and they never work as well again with a new battery.  But can not spend money on new ph']
# [{'first letter': 'n', 'last letter': 'e'}, '@aimee_bernard how bout iming a sad friend? ']
# [{'first letter': 'n', 'last letter': 'e'}, 'on the train to work again n really cba 2day!!  Want my bed ']
# [{'first letter': 'n', 'last letter': 'e'}, '@PixieElla that sucks Pixie  at least your home to relax']
# [{'first letter': 'p', 'last letter': 'e'}, '@gloomyrain2 the academy is are aweesome! ']
# [{'first letter': 'p', 'last letter': 'e'}, 'I am now reading a manga. ']
# [{'first letter': 'p', 'last letter': 'e'}, "@psandalio it's ok! totally diff biz plan. unless you want to do a viet truck now... "]
# [{'first letter': 'n', 'last letter': 'e'}, '@S_dott sounds like fun, oh the memories   how long will u be here?']
# [{'first letter': 'n', 'last letter': 'e'}, 'Hello world!!! Another day of downtimes in network  Getting be flustrated  Good Luck for a day!']
# [{'first letter': 'n', 'last letter': 'e'}, "@jen004   oh so sorry hun....that must be really hard!!!  We'll be here for you!!      Bella"]
# [{'first letter': 'p', 'last letter': 'e'}, 'sitting outisde in the beautiful weather  Love it could sit here all day']
# [{'first letter': 'p', 'last letter': 'e'}, 'Sushi, sake, and Wired.  Happy Sunday.  ']
# [{'first letter': 'p', 'last letter': 'e'}, "I'm heading to dreamland...have to work tomorrow! Then to a going away party for a little bit after work! Good Night to you all! "]
# [{'first letter': 'n', 'last letter': 'e'}, '@bt http://twitpic.com/87l4m - I just woke and this was the first thing I read... so sad ']
# [{'first letter': 'p', 'last letter': 'e'}, '@StephenNorthcut @robtlee have fun this week gentleman ']
# [{'first letter': 'n', 'last letter': 'e'}, 'shoot, http://svnbook.red-bean.com is down ']
# [{'first letter': 'n', 'last letter': 'e'}, "Okay i don't like sharing you "]
# [{'first letter': 'n', 'last letter': 'e'}, "Owww, the LOUDEST pop i've ever herd a body make, just came outta my hip. Owwwwww. "]
# [{'first letter': 'n', 'last letter': 'e'}, "@yamb that's because of the wookiee's prejudice "]
# [{'first letter': 'p', 'last letter': 'e'}, 'i just watchd 2 movies at hoyts 2day ugh..but then again yay!! LOL 17 again was awesome but monster vs aliens was OK but cute and boring ']
# [{'first letter': 'p', 'last letter': 'e'}, '@Ang_acf do dvd ']
# [{'first letter': 'n', 'last letter': 'e'}, "@selenagomez i haven't even seen it once "]
# [{'first letter': 'p', 'last letter': 'e'}, 'had a great evening ']
# [{'first letter': 'p', 'last letter': 'e'}, 'OH HELL YES! The OC is on ']
# [{'first letter': 'p', 'last letter': 'e'}, '@Marcus_grayus Hey! its Moosehead here! Try this distributor to help you find MH: Pierhead Purchasing Ltd. Tel: 011 44 1322 662377 ']
# [{'first letter': 'n', 'last letter': 'e'}, "@lindseycholmes free?..I only put 100 on the course..I aint got da 300+ 2 finish pay it off..that's what I cant tell them   .."]
# [{'first letter': 'n', 'last letter': 'e'}, "Paul did a mini photo shoot at eugene ... Probably can't post pics until tomorrow ... Can't find camera's usb cable  #at"]
# [{'first letter': 'n', 'last letter': 'e'}, '@lusid2029 I will let you know as soon as I figure it out... sorry about the mix up; i was supposed to get off work an hour ago ']
# [{'first letter': 'n', 'last letter': 'e'}, '@ritarams Hey say me something  haha now that you in love, love, love (8) forget about me? haha luv ya and im so happy because u happy']
# [{'first letter': 'n', 'last letter': 'e'}, '@tweetvisor what happened to my real-time feed? Now friend feed is just like the Twitter website ']
# [{'first letter': 'p', 'last letter': 'e'}, 'off to the beach ']
# [{'first letter': 'n', 'last letter': 'e'}, 'Today was supposed to be my day off   Oh well!  Off to work in approx. 10 minutes.']
# [{'first letter': 'p', 'last letter': 'e'}, "I'm gonna see wot the world of twitter has 2 offer. so far, its not looking 2 bad "]
# [{'first letter': 'n', 'last letter': 'e'}, "I haven't updated my site in a while...I thiink I should do that later...gosh so friggin bored. "]
# [{'first letter': 'n', 'last letter': 'e'}, '@Dylan1031 I know right?! Sexy Stewy! @OrdinaryGirl627 I miss the hair too  But she must rock for JJ ;)']
# [{'first letter': 'n', 'last letter': 'e'}, 'i wanted a mushroom tamal. i got a green tamal instead  i was so upset']
# [{'first letter': 'n', 'last letter': 'e'}, '@VOMalleyPhoto im in Paris doing some dj skits and working for a photog agency; but downside is wisdom teeth growing in ']
# [{'first letter': 'n', 'last letter': 'e'}, "just came back frm the dentist, wow my mouth is feeling rough, i can't feel a thing! or taste at thing!, I WANT TO ENJOY FOOD AGAIN "]
# [{'first letter': 'n', 'last letter': 'e'}, "Just added up how much I spent today. Considering I didn't get funding for this fall I better start cutting back on stuff! "]
# [{'first letter': 'n', 'last letter': 'e'}, 'This is not! looking good  http://bit.ly/11gUqQ very strange ']
# [{'first letter': 'p', 'last letter': 'e'}, 'Voted for David as MrTwitterUniverse! did you all? You can vote every 20 mins. He is makin a climb... ']
# [{'first letter': 'p', 'last letter': 'e'}, 'Yay! Sitting on my new sofa. So comfy ']
# [{'first letter': 'p', 'last letter': 'e'}, 'Going to bed now i think  school tomorrow (N)  night night  xxx']
# [{'first letter': 'p', 'last letter': 'e'}, 'going to the Brewers Gameee ']
# [{'first letter': 'p', 'last letter': 'e'}, '@emoprinxexa Hi there sweetie! ']
# [{'first letter': 'n', 'last letter': 'e'}, '@Pansywhacker @KangarooGav Just saw that Will from the Inbetweeners was at the Union in November. Gutted ']
# [{'first letter': 'n', 'last letter': 'e'}, "@iMarkyP I did mate. Think I'm going to have to delete backups in iTunes then factory restore all the way from 2 thru to 3.0 "]
# [{'first letter': 'p', 'last letter': 'e'}, "@crispyteriyaki LOL! best mind you words! 'specially around these parts!  ????????"]
# [{'first letter': 'n', 'last letter': 'e'}, "@zoeinthecity Dali was amazing. 200 works in one place - shame it's not travelling to brisvegas  how was davinci?"]
# [{'first letter': 'n', 'last letter': 'e'}, "I'm waiting for the next 43 visitors on http://short.to/g9l0 ... "]
# [{'first letter': 'p', 'last letter': 'e'}, '@MissLeopardStar im more of a taylorham n cheese kinda girl!! ']
# [{'first letter': 'n', 'last letter': 'e'}, "The chicken is roasting, and the vegetables and Yorkshire puds are ready to go. I guess I'd better start on the ironing "]
# [{'first letter': 'n', 'last letter': 'e'}, '@RubyRose1  http://twitpic.com/7vikp incase u can hoook me up even tho im way late ']
# [{'first letter': 'p', 'last letter': 'e'}, '@neotigress Yes, oils are very forgiving ']
# [{'first letter': 'p', 'last letter': 'e'}, 'Good morning ']
# [{'first letter': 'n', 'last letter': 'e'}, "I'm very very very HUNGRY "]
# [{'first letter': 'n', 'last letter': 'e'}, '@Kal_Penn The thing that sucks the most is that you were the one I was most excited for, even before I knew who the final team would be. ']
# [{'first letter': 'p', 'last letter': 'e'}, 'going to bigreen tomororw ']
# [{'first letter': 'n', 'last letter': 'e'}, '@ work . . bored ']
# [{'first letter': 'n', 'last letter': 'e'}, "@DULCECUBANA  I don't know anyone else  I feeling like a stalker... lol  &quot;following&quot; is such a stalker move hahahahah"]
# [{'first letter': 'p', 'last letter': 'e'}, 'I wanna thank Jesus Christ for giving me life &amp; a purpose... to inspire &amp; serve people ']
# [{'first letter': 'n', 'last letter': 'e'}, "@bassandtr3ble  i can't make it tomorrow.  so sad!!"]
# [{'first letter': 'n', 'last letter': 'e'}, 'its too cold  athletics carnival tomorrow']
# [{'first letter': 'p', 'last letter': 'e'}, '@ZoinksYo Just alot of girly stuff i have already and dont need  clothes,jewelry, 9 pairs of sunglasses, Etcc etcc.. lol']
# [{'first letter': 'p', 'last letter': 'e'}, 'Saku has to start to his Chick Flick List ']
# [{'first letter': 'p', 'last letter': 'e'}, 'just got back from the pool ']
# [{'first letter': 'p', 'last letter': 'e'}, '@DetSportsBeat Why thank you! ']
# [{'first letter': 'p', 'last letter': 'e'}, '@KimberlyCole1 I have done that so many times LOL, forget to put the proper footwear on!  Sometimes in socks!  ']
# [{'first letter': 'n', 'last letter': 'e'}, '@thedeadbaby why ']
# [{'first letter': 'n', 'last letter': 'e'}, 'http://twitpic.com/7vqa4 - I even knocked into a cactus and it retaliated ']
# [{'first letter': 'p', 'last letter': 'e'}, "@jacobbrwr Yes. Yes I would. You'd be welcome to stay with us haha. I'll sleep on the couch "]
# [{'first letter': 'p', 'last letter': 'e'}, "@SimPlyMoReNa I'm lovely  bout to go job hunting with sam , yu ?"]
# [{'first letter': 'p', 'last letter': 'e'}, 'boys over flowers ']
# [{'first letter': 'n', 'last letter': 'e'}, 'p.s. to the mike weatherly blog, he better not be leaving the show! I really like DiNozzo!  Next tues. is gonna be crazy!']
# [{'first letter': 'n', 'last letter': 'e'}, 'is doing her dreaded assignment ']
# [{'first letter': 'n', 'last letter': 'e'}, 'Master bedroom carpet is now gone.  Time to treat the floor. ']
# [{'first letter': 'n', 'last letter': 'e'}, 'back to work tomorrow !!   Very stressed O hop everything will go well']
# [{'first letter': 'n', 'last letter': 'e'}, '@poppy_dog thankfully yes. I felt really bad.  ']
# [{'first letter': 'p', 'last letter': 'e'}, "yummy indian food for lunch today from Kumar's "]
# [{'first letter': 'p', 'last letter': 'e'}, '@SaulaSmurf I like your videos  Good job.']
# [{'first letter': 'p', 'last letter': 'e'}, "@krayfish ha ha yes in a hole in the road next to the octopus's garden "]
# [{'first letter': 'n', 'last letter': 'e'}, 'And yeah they wont let me before. I guess clearing up history and cache worked... I cant acces facebook though. ']
# [{'first letter': 'p', 'last letter': 'e'}, 'Heading to the pool with @jimmygraham! ']
# [{'first letter': 'p', 'last letter': 'e'}, '@ionwen im good thanks, having a wee drinky poohs and got a curry for later  hows you chicky??!xxx']
# [{'first letter': 'n', 'last letter': 'e'}, 'my throat is swollen and tight, and health services is closed ']
# [{'first letter': 'n', 'last letter': 'e'}, '@ jennybennytoe Miss you!  Its poppin!']
# [{'first letter': 'p', 'last letter': 'e'}, '@danniFNB i am gooood  how about yourself?']
# [{'first letter': 'n', 'last letter': 'e'}, "@ariannypilarte I don't know any bowtie songs. "]
# [{'first letter': 'n', 'last letter': 'e'}, "@easycompany510 Hahah, true, true. I was 5'2 in 5th! Haven't grown since, though.  Plus, she was prob just trying to spit game. LOL"]
# [{'first letter': 'p', 'last letter': 'e'}, '@dalerankine You mean also in NZ and I should just stay at home in the rain? ']
# [{'first letter': 'p', 'last letter': 'e'}, "so wow this is like one of the few times i use twitter i think i'm gonna start using it more  ha ha"]
# [{'first letter': 'n', 'last letter': 'e'}, '@mizzSupaStar  dam u leavin forreal?']
# [{'first letter': 'p', 'last letter': 'e'}, 'Listening to Sexify My Love - great song  - How is everyone today??']
# [{'first letter': 'n', 'last letter': 'e'}, 'left my phone at work ']
# [{'first letter': 'p', 'last letter': 'e'}, '@SheilaRB57 Awesome! Good luck with that Job search..  Hope you find something ideal soon.. ']
# [{'first letter': 'n', 'last letter': 'e'}, 'the seas are rough today....my stomach is not gonna be happy ']
# [{'first letter': 'n', 'last letter': 'e'}, "can't hang out with jay and ann...too much cleaning and work to do "]
# [{'first letter': 'n', 'last letter': 'e'}, "@lauramendon yeah, i know! yay!!! friday off! long weekend! but i'll be stuck indoors doing assignments and homework "]
# [{'first letter': 'n', 'last letter': 'e'}, "@TheEllenShow Ellen you know your online store doesn't selln Ellen water? neither does ebay  that's all I want for my birthday :}"]
# [{'first letter': 'p', 'last letter': 'e'}, 'what a beautiful day in seattle, so im doing indoor rock climbing. ']
# [{'first letter': 'n', 'last letter': 'e'}, "i'm sooo over study- last final 2moz morning....so will be up all night &amp; probably only get like 4 hrs sleep "]
# [{'first letter': 'n', 'last letter': 'e'}, "@raine33 hope you and your friends aren't part of the hate  he's not my fave either, but they're just cruel! #dannygokeyislove"]
# [{'first letter': 'n', 'last letter': 'e'}, 'has sleeping issues....major ones.  just started a xanga...well see how long that lasts']
# [{'first letter': 'n', 'last letter': 'e'}, 'i Want an iphone  #Squarespace']
# [{'first letter': 'n', 'last letter': 'e'}, "6am and I'm awake starving "]
# [{'first letter': 'n', 'last letter': 'e'}, '@__stephanie yay!! thanks for reminding mee!! i went to go follow him b4 but my comp shut down  then i forgot hehe hes soo cute!!']
# [{'first letter': 'n', 'last letter': 'e'}, 'Arrived at Gatwick far too early and got more than an hour until check-in even opens ']
# [{'first letter': 'p', 'last letter': 'e'}, 'Middle school old navy meeting packing call text ']
# [{'first letter': 'n', 'last letter': 'e'}, 'quitting my piano lesson this month. i was never excellent ']
# [{'first letter': 'p', 'last letter': 'e'}, '@FillLight Been out running errands but listening to game in the car.  Magic has been doing just fine without my Twitter comments. ']
# [{'first letter': 'p', 'last letter': 'e'}, "chillin' with @amycock  "]
# [{'first letter': 'n', 'last letter': 'e'}, 'Also, did they not show the candidates at all when the awards were being announced? I wanted to see Kris get all excited, and then not... ']
# [{'first letter': 'n', 'last letter': 'e'}, '@letmesign Logging into album myorli89 : famous password... OOOH DO I NEED A PASS? ']
# [{'first letter': 'p', 'last letter': 'e'}, '@billyraycyrus greeting to miley for Peruvian Fan : Ale ! ']
# [{'first letter': 'n', 'last letter': 'e'}, 'I pray to God that those pics that came out are not Miley Cyrus. ']
# [{'first letter': 'p', 'last letter': 'e'}, '@kevjumba It was nice seeing ya at the live event. The crowd loved ya! ']
# [{'first letter': 'p', 'last letter': 'e'}, 'spending bonding and quality time with my sister watching ncis and eating a taquito ']
# [{'first letter': 'n', 'last letter': 'e'}, 'do nothing  http://plurk.com/p/13suw6']
# [{'first letter': 'n', 'last letter': 'e'}, "@prk215 thanks I'll go watch it nw. Did u c on perez they performed in the street  I want to meet them"]
# [{'first letter': 'n', 'last letter': 'e'}, 'I hate the Wagga cinema! It is gay! Stupid cinema removing that movie from the website therefore crushing all my dreams of seeing it!! ']
# [{'first letter': 'p', 'last letter': 'e'}, '@ewarnock Thank you!  ']
# [{'first letter': 'p', 'last letter': 'e'}, '@jenniferstuart thanks for including my print , jen!!! what a great post. i especially love the last grouping. ']
# [{'first letter': 'n', 'last letter': 'e'}, "@mimiandkarl what's new? when it rains, it's off!! Haha huhu "]
# [{'first letter': 'p', 'last letter': 'e'}, 'Benjamin Grey never fails to make me smile ']
# [{'first letter': 'p', 'last letter': 'e'}, '@XdragonmutleyX yes defently that is what make you totally awsomeeee ']
# [{'first letter': 'p', 'last letter': 'e'}, '@omgitsalyssa http://twitpic.com/66fxv - Awww, so cute and sweet! ']
# [{'first letter': 'p', 'last letter': 'e'}, "@FeministBreeder At first glance, I say, 'Wow!' That looks really good. "]
# [{'first letter': 'p', 'last letter': 'e'}, 'lexy - novice  this has been keeping me up all night. i need to get up early... damn']
# [{'first letter': 'p', 'last letter': 'e'}, '@jonomallanyk @philpaulo @stevenwbrown wake up boys!!! game time!! ']
# [{'first letter': 'n', 'last letter': 'e'}, 'leaving the city today.   back to school tomorrow.']
# [{'first letter': 'n', 'last letter': 'e'}, '@nataliebailey  Paranoia sucks! Feel better soon friend.']
# [{'first letter': 'p', 'last letter': 'e'}, 'awww hl is just the sweetest. ']
# [{'first letter': 'p', 'last letter': 'e'}, 'Emociioneeei com o 1Âº trailler de New Moon [ http://bit.ly/15g8G2  ] aiai.. suspirando ']
# [{'first letter': 'p', 'last letter': 'e'}, '@scottreedstl Awesome!  Hope the weekend is amazing!  ...and pretend Nat &amp; I are visiting too... just in Nashvegas instead of St. Louis. ']
# [{'first letter': 'p', 'last letter': 'e'}, "@OTB508 They're so FREAKIN' good.... *uhhhhhhhhhhh* *huhhhhhhhhh* "]
# [{'first letter': 'p', 'last letter': 'e'}, "let's make this day better "]
# [{'first letter': 'p', 'last letter': 'e'}, "New #photog on Twitter, my buddy Phil  @ppcass Let's show him some #togsfollow love "]
# [{'first letter': 'p', 'last letter': 'e'}, "@smallz2007 now I gotta teach her how to do her times tables I have no idea how I'm going to explain it to her where she'll get it HELP "]
# [{'first letter': 'p', 'last letter': 'e'}, '@elizadc i ate nothing for bfast, butter cookies fer lunch and a mango for dinner. ']
# [{'first letter': 'n', 'last letter': 'e'}, "I may have graduated, but I still feel like everything's basically falling apart. "]
# [{'first letter': 'n', 'last letter': 'e'}, '@MizzHanley I KNO RITE! THAT HAS NEVER HAPPEN 2 ME B4.......LIKE NEVA!!! EVA!!! DEM AIN KNO WA HAPPEN 2 ME YET ']
# [{'first letter': 'n', 'last letter': 'e'}, '@theosko 8th ']
# [{'first letter': 'n', 'last letter': 'e'}, "I just got back from an amazingly fun day at the local amusement park! It was so great... until I started feelin' sick. x_x Has flu now. "]
# [{'first letter': 'n', 'last letter': 'e'}, '@Didsbury_  but i wanna meet jareddd and the saturdaayss  ahha']
# [{'first letter': 'p', 'last letter': 'e'}, 'At the rehersal dinner for the wedding of Alice Jackson and Taylor Bradley... Two blessings in my life ']
# [{'first letter': 'n', 'last letter': 'e'}, "wonders why no one ever invites her to the football  Just because I detest all sports, doesn't mean I don't want to watch them."]
# [{'first letter': 'p', 'last letter': 'e'}, 'says Good Afternoon!  http://plurk.com/p/wxd2v']
# [{'first letter': 'n', 'last letter': 'e'}, "@Nisha_L yeahh  haha.. after a long break, i'm kinda getting back into it with a vengeance.. it's gnna get worse when I get my HDTV tmr.."]
# [{'first letter': 'n', 'last letter': 'e'}, '@lordofsquad Crush my dreams  lol']
# [{'first letter': 'p', 'last letter': 'e'}, '@myhti Now it works ']
# [{'first letter': 'p', 'last letter': 'e'}, "@ilaura_etsy I'm sure I c/ have done better-that's why I'm amazed at how well all 3 of my kids do/did in school! "]
# [{'first letter': 'p', 'last letter': 'e'}, '@STASIAJADE hey chic congrats on ur high school graduation!! erlcome 2 the real world lol ']
# [{'first letter': 'p', 'last letter': 'e'}, "@WiltingSoul  Goodnight, sweet dreams.  It's 10.22 a.m. in the morning here "]
# [{'first letter': 'n', 'last letter': 'e'}, 'tears in heaven, such a sad song  but beautiful all the same.']
# [{'first letter': 'n', 'last letter': 'e'}, "@P0150N0U5F15H I know it's not there "]
# [{'first letter': 'p', 'last letter': 'e'}, "hello! I've bought baking ingredients and will stare blankly at them til inspired. D**n bake sale. But duck in oven and looks yum "]
# [{'first letter': 'n', 'last letter': 'e'}, 'Math tutor @ 3 today  At least only 4 more days of school']
# [{'first letter': 'n', 'last letter': 'e'}, 'Early morning - no sun either here @lisarosendahl  ']
# [{'first letter': 'p', 'last letter': 'e'}, '@thriftymom What are #primal pants made out of? ']
# [{'first letter': 'n', 'last letter': 'e'}, '@JJtheflexdoll yeah!!!! forshhowwa girlfriend! no i didnt  im sooo hopeless! ummm i got burts bees lip gloss, uh..mascara and foundation.']
# [{'first letter': 'p', 'last letter': 'e'}, 'lastnight watched the award show, n super well done to miley n the twilight cast! amazing loved it n cant wait till new moon!  -karissa']
# [{'first letter': 'p', 'last letter': 'e'}, "My lovely Twilight guys, you're the best! "]
# [{'first letter': 'n', 'last letter': 'e'}, '@gagadailydotcom Yaaaaay. I missed GaGaDaily. ']
# [{'first letter': 'p', 'last letter': 'e'}, '@littleunred runy baby run ']
# [{'first letter': 'n', 'last letter': 'e'}, 'just realized how much i need/want a certain someone ']
# [{'first letter': 'p', 'last letter': 'e'}, 'Working my cheeks off tonight. New case being delivered for my iphone tomorrow. ']
# [{'first letter': 'p', 'last letter': 'e'}, 'http://twitpic.com/67eai - J Crew just inspired me! Summer 09 ']
# [{'first letter': 'n', 'last letter': 'e'}, 'and still they havnt arrived. getting stessed at download tickets not having arrived yet!! ']
# [{'first letter': 'n', 'last letter': 'e'}, 'is soooo fucking tired and just wants to sleep ']
# [{'first letter': 'p', 'last letter': 'e'}, " @SandyU @MightyBoognish @kittyireland It's light with a bit of punch. Mission=San Francisco gin, Mexican liqueur, seemed an apt name."]
# [{'first letter': 'n', 'last letter': 'e'}, "@SantanaK I'm still up too "]
# [{'first letter': 'p', 'last letter': 'e'}, '@semperamy09 why not let it get out of hand?  W/ as recent as twitter has become popular, you could be the next tila tequila. ']
# [{'first letter': 'n', 'last letter': 'e'}, "@mhmlauren  i'm not in the city yet. we're going tomorrow. I'll take a picture of the city just for you and text it to you"]
# [{'first letter': 'p', 'last letter': 'e'}, '@MJNuts Brought the site up and will check it out when I get back from eating some dinner.   Thanks for all of them!  Send more - yay!']
# [{'first letter': 'p', 'last letter': 'e'}, 'Today shopping with Danielle. ']
# [{'first letter': 'n', 'last letter': 'e'}, 'Okay why do i always wake up 3 hrs early... FML ']
# [{'first letter': 'p', 'last letter': 'e'}, 'says goodnight  http://plurk.com/p/xegof']
# [{'first letter': 'p', 'last letter': 'e'}, '@DsHooahgirl there should be a chp in every story about playdough  haha']
# [{'first letter': 'n', 'last letter': 'e'}, "Injured all over. But I can play with bad knees, wrists, and shin splits. It's my back that could take me out. Get the x-ray today. "]
# [{'first letter': 'p', 'last letter': 'e'}, '@chattykatty520 Three hours of class would be more awesomer! ']
# [{'first letter': 'p', 'last letter': 'e'}, 'ok home now...just got some smart start &amp; special K strawberries &amp; yogurt cereal on sale @ riteaid ']
# [{'first letter': 'p', 'last letter': 'e'}, '@asiamoneiqh4eva we qood  aww congrats you two qonna celebrate ?']
# [{'first letter': 'n', 'last letter': 'e'}, "@2ewgunnciz Hey there i've been sick  and not happy about it"]
# [{'first letter': 'p', 'last letter': 'e'}, 'getting ready for bed....goodnight world! ']
# [{'first letter': 'n', 'last letter': 'e'}, "@SavingEveryday Pretty good. Son had an MRI on his knee y'day. Hope to know the results Mon. Probably surgery "]
# [{'first letter': 'p', 'last letter': 'e'}, '@pornprom But today we have government always in 0.9 rc with a new constitution coming up again, and civil servant 0.1 ']
# [{'first letter': 'n', 'last letter': 'e'}, 'Ive had a lovely day with my kiddies. Tyler turned 4. Now he is under the weather ']
# [{'first letter': 'n', 'last letter': 'e'}, 'Up  sup twitterheads.']
# [{'first letter': 'p', 'last letter': 'e'}, 'http://twitpic.com/65v13 - Important team meeting in progress ']
# [{'first letter': 'n', 'last letter': 'e'}, 'http://tinyurl.com/ry9wap Hi. Check my pictures! I cant upload more pics here for some reason  Hope we will match each other.  I can s ...']
# [{'first letter': 'p', 'last letter': 'e'}, 'Just watched new moon trailor, Pretty cool, better than expected Lol, better director, bigger budget. BETTER MOVIE ']
# [{'first letter': 'n', 'last letter': 'e'}, 'At work on a Saturday  damn it.']
# [{'first letter': 'p', 'last letter': 'e'}, 'Mami just arrived with a loaf of lemon meringue ']
# [{'first letter': 'n', 'last letter': 'e'}, '&lt;3 Elbow. To bad pinkpop and lowlands are solded out  I really wanted to go this year..']
# [{'first letter': 'n', 'last letter': 'e'}, "Don't find the solution for the &quot;jumping&quot; div with jQuery slideToggle... Have to bookmark more sites when I needed them the first time "]
# [{'first letter': 'p', 'last letter': 'e'}, "Sitting at Emily's house! Seeing Vante tonight? "]
# [{'first letter': 'p', 'last letter': 'e'}, 'Anybody have anything exciting for me to do over the bank holiday weekend, Need to avoid the internetless, lonely, boring room ']
# [{'first letter': 'n', 'last letter': 'e'}, "allergy = no fun   i miss my turtles and boys. :'("]
# [{'first letter': 'p', 'last letter': 'e'}, '@temptalia .. I am checking your project temptalia gallery and I like it a lot!  That is an excellent idea  and thanks for charing it ']
# [{'first letter': 'p', 'last letter': 'e'}, "i'll brb .. taking a break and gonna watch sky high "]
# [{'first letter': 'n', 'last letter': 'e'}, 'Another iPhone rant: 1.5 hrs into backup, stopped because only ~10% progress. Had to reinstall all apps via iTunes to fix. ']
# [{'first letter': 'p', 'last letter': 'e'}, 'so sleepy i cant even spell right....good night to all ']
# [{'first letter': 'p', 'last letter': 'e'}, 'Slept til 7:30 today. And it was nice. ']
# [{'first letter': 'p', 'last letter': 'e'}, '@maysoonShaladi Hello stranger  Love the quote..hope to see you on here more often.You get some amazing people on here..come tweet more x']
# [{'first letter': 'n', 'last letter': 'e'}, 'people are at #awaresg either for a fight or to watch a fight. sigh  does civil society gets to be civil?']
# [{'first letter': 'p', 'last letter': 'e'}, 'Good... er... morning-ish people ']
# [{'first letter': 'n', 'last letter': 'e'}, 'going to seymour in a a couple a hours  Too bad the twitter stopped working on my phone.']
# [{'first letter': 'n', 'last letter': 'e'}, '@elizabethskene  I wish I could come to MI just to see you.']
# [{'first letter': 'n', 'last letter': 'e'}, 'mornin twitterans.... 2day is gonna b a long day! work til 6 ']
# [{'first letter': 'p', 'last letter': 'e'}, "@skingirl69 dunno what it pays, i'll send him a text later to remind him to hint around to see what the deal is... "]
# [{'first letter': 'p', 'last letter': 'e'}, '@raskenbo thank you for your kind words. I hope my jaded-ness will pass with time... ']
# [{'first letter': 'p', 'last letter': 'e'}, '@gerrymay thanks so much!  voting ends may 25, so we have 13 spots to go til then  thanks for helping us out!']
# [{'first letter': 'n', 'last letter': 'e'}, "Love you Johnjay VanEs and Rich Berra... can't listen to you for two weeks  Miss you guys in my mornings!"]
# [{'first letter': 'p', 'last letter': 'e'}, '@krisloray1226 yes u do I thought u were snow white at first ']
# [{'first letter': 'p', 'last letter': 'e'}, "Good morning  it's a new month... time to be productive!"]
# [{'first letter': 'p', 'last letter': 'e'}, 'Looking forward to watching French Open Highlights every night this week on Channel 9! I FINALLY get to watch some of the sport I love ']
# [{'first letter': 'p', 'last letter': 'e'}, "Just need 4 more followers to hit 100. Any takers? I'm very nice "]
# [{'first letter': 'n', 'last letter': 'e'}, "@pinklou81 No cos our school's crap! Last year I had to stay till all exams were over, now I'm in year 12 they don't think we need it "]
# [{'first letter': 'p', 'last letter': 'e'}, '@heathermaexoxo How did you meet Chester French? Is he a musician? And whatï¿½s in DC? New job? ']
# [{'first letter': 'p', 'last letter': 'e'}, 'went to digress bar on Friday night, really good fun and a nice easy going bar. nice barmen too ']
# [{'first letter': 'n', 'last letter': 'e'}, 'Tomorrow is going to be one of the most horrible days ever ']
# [{'first letter': 'p', 'last letter': 'e'}, 'Just woke up from the most relaxing nap ever ']
# [{'first letter': 'n', 'last letter': 'e'}, 'Cute necklace bought from Laila Rowe fell apart first time I tried to wear it   I guess you get what you pay for...']
# [{'first letter': 'p', 'last letter': 'e'}, 'woot, i made it to the last bus to alphen  sleeping at home tonight.']
# [{'first letter': 'p', 'last letter': 'e'}, '@myogis thx for the rt M, hows halifax this am? TO is cool, sunny, blue sky  looks like a lovely day.']
# [{'first letter': 'p', 'last letter': 'e'}, 'feeling a quick nap before running some errands. text ? keep me company ']
# [{'first letter': 'n', 'last letter': 'e'}, '@KimiBananas new iphone 3g ooooor blackberry lol i got so used to have internet everywhere ']
# [{'first letter': 'n', 'last letter': 'e'}, "They won't fit "]
# [{'first letter': 'p', 'last letter': 'e'}, '@haveheartcate stfu, hoe!   lubb you']
# [{'first letter': 'n', 'last letter': 'e'}, "Poor Ed McMahan died....that's too bad.  And also Jon and Kate divorcing...poor kids."]
# [{'first letter': 'n', 'last letter': 'e'}, 'ahahahahha ohhh yeahhh! but I think Mileys guna log off twitter  I gotta do stuff, like shower and eat and change!lol byebye&lt;3(:']
# [{'first letter': 'p', 'last letter': 'e'}, '@taylorswift13 hahahaa I can so see u doing that &quot;IM ON A BOAT!!!&quot; haha that song is sooo funny ']
# [{'first letter': 'p', 'last letter': 'e'}, "@LendogPDX I haven't gotten my scarf yet... but @shawnlevy assures me I will.  "]
# [{'first letter': 'p', 'last letter': 'e'}, 'Man vs. Wild with will ferrell. Hahaha awesome.  Bed times for this girl ']
# [{'first letter': 'n', 'last letter': 'e'}, 'My cat is sick ']
# [{'first letter': 'p', 'last letter': 'e'}, 'watching the lakers game with my man!  ILY']
# [{'first letter': 'n', 'last letter': 'e'}, "I'm just gone. then learn a little bit and then sleep. tomorrow last day at school "]
# [{'first letter': 'n', 'last letter': 'e'}, 'I am craving criolla empanadas... But settling for McDonalds instead. So not the same ']
# [{'first letter': 'p', 'last letter': 'e'}, '@joocemusic : hey you ']
# [{'first letter': 'n', 'last letter': 'e'}, "@howarddbear I wont leave you Bear. Youre my only friend  weep weep. Bloody monkey. I hate him. I said this morning. No M's. NO M's."]
# [{'first letter': 'n', 'last letter': 'e'}, 'Seriously gonna go crazy with this essay! Wanna go home badly ']
# [{'first letter': 'p', 'last letter': 'e'}, '@Yemerej Coffee? ']
# [{'first letter': 'p', 'last letter': 'e'}, '@lasvegasjen Think the Hangover movie boosted the #vegas topic.. on wanting to come here lol thats good for us! ']
# [{'first letter': 'p', 'last letter': 'e'}, '@itscurtains4u I hear yah  Howdy?']
# [{'first letter': 'p', 'last letter': 'e'}, '@paythedevil Hiya  How are you man? Who is Patty? Some friend of you or ?']
# [{'first letter': 'n', 'last letter': 'e'}, "Business English final went great, now it's for the dreaded resistance final! 3 questions, 25, 25 and 50. OMG. "]
# [{'first letter': 'p', 'last letter': 'e'}, '@dogsmycopilot Thats right  ']
# [{'first letter': 'p', 'last letter': 'e'}, "@dhimant double whammy dude, turns out I also know the guys in the next story 'Skills for Kids', good work all around "]
# [{'first letter': 'n', 'last letter': 'e'}, "I don't understand why some people are so darn confusing "]
# [{'first letter': 'p', 'last letter': 'e'}, '@x3Lovebug iikrr ? What hahaha . I want your update # 1000  Mwah .']
# [{'first letter': 'p', 'last letter': 'e'}, '@olixx sounds quite demanding ']
# [{'first letter': 'n', 'last letter': 'e'}, "@gerrytan congrats. i don't think i'm gonna make it in time "]
# [{'first letter': 'n', 'last letter': 'e'}, 'i really need 2 keep my following people under 200..otherwise i cant keep up with updates...i cleaned it up last week and im again over ']
# [{'first letter': 'p', 'last letter': 'e'}, 'loves that the house she owns is 8 minutes from the yoga studio! ']
# [{'first letter': 'p', 'last letter': 'e'}, '@lorner96 Yeah, thats how i have it (in the Tray) ']
# [{'first letter': 'n', 'last letter': 'e'}, 'i have to move to the boring old PC.... Bye bye Mac!! ']
# [{'first letter': 'p', 'last letter': 'e'}, "Today's shoot was naked and fun   So cool not to worry about wardrobe.  Now back to editing "]
# [{'first letter': 'n', 'last letter': 'e'}, 'Oh thats heart breaking. A female cardinal just smashed into the window and fell. I think its dying ']
# [{'first letter': 'n', 'last letter': 'e'}, 'needs something to do it feels like I have no life ']
# [{'first letter': 'p', 'last letter': 'e'}, 'Bed after a long day.  good night']
# [{'first letter': 'n', 'last letter': 'e'}, 'ahh two movies i still need to wait for forever to come to see- new moon and harry potter  hurry! the trailers are killing meee']
# [{'first letter': 'p', 'last letter': 'e'}, '@Arvind_srid Well, working on a project tht requires more focus &amp; concentrtion than I m giving right now..... though der improvement.. ']
# [{'first letter': 'p', 'last letter': 'e'}, '1:11 ...make a wish ']
# [{'first letter': 'p', 'last letter': 'e'}, 'at kimmys,baby shower tomorrow ']
# [{'first letter': 'p', 'last letter': 'e'}, '@EADave HEY HEY ready to come to oklahoma? ']
# [{'first letter': 'n', 'last letter': 'e'}, "@junecares hmm. so i missed my BFF @ the court huh..it's okay anyway.. really need to take a rest last night.. still not so fine today "]
# [{'first letter': 'p', 'last letter': 'e'}, 'excitement ']
# [{'first letter': 'p', 'last letter': 'e'}, "I'm back in action...my twitter on my phone is workin again "]
# [{'first letter': 'n', 'last letter': 'e'}, 'Leaving Lock Haven. ']
# [{'first letter': 'n', 'last letter': 'e'}, 'Fuck sake, I would have sworn it was Sree, now Beinazir will go ']
# [{'first letter': 'p', 'last letter': 'e'}, '@Kimmy6313 Oh man, it was sooo sad, but good.  Wow.. I am watching L&amp;O: UK. LOLZ! ']
# [{'first letter': 'p', 'last letter': 'e'}, 'who needs to sleep in on a sunday anyways? ']
# [{'first letter': 'p', 'last letter': 'e'}, '@jarondo My pleasure! ']
# [{'first letter': 'n', 'last letter': 'e'}, "On the last train before the hotel. In get changed and back into town, still haven't eaten anything!  I'll grab a dairy milk or something!"]
# [{'first letter': 'p', 'last letter': 'e'}, 'Well, what a loonngg night! .......... Playing the Sims 3! Such an awesome game! GO GET IT, hours of fun building!  x']
# [{'first letter': 'p', 'last letter': 'e'}, '23 followers.. ']
# [{'first letter': 'p', 'last letter': 'e'}, "@markce i block 2 or 3 a week it seems.  if some1 is following 3k people I'm pretty sure they don't need 2 c pictures of my hounds. "]
# [{'first letter': 'p', 'last letter': 'e'}, '@Bloodywind yeah I ate it. Was too tired &amp; hungry to complain ']
# [{'first letter': 'n', 'last letter': 'e'}, "my phone won't let me tweet  i was going to stay in my room, do homework and tweet obsessively but i can't so i will here."]
# [{'first letter': 'p', 'last letter': 'e'}, 'the heat makes me tired, but thats ok. i have no hmework, so wat is there to complain about? ']
# [{'first letter': 'n', 'last letter': 'e'}, '@exitmould D: i waaaaant. but unfortunately, no. ']
# [{'first letter': 'n', 'last letter': 'e'}, "@whoopthis Sorry about that man, but that's how people are sometimes "]
# [{'first letter': 'n', 'last letter': 'e'}, 'At the office doing some work.  I told the landlord yesterday that I will be moving out of the office on July 1 ']
# [{'first letter': 'p', 'last letter': 'e'}, 'I enjoy spending time with my family and friends. Enjoy being near water and mountains and I love traveling...just not flying ']
# [{'first letter': 'p', 'last letter': 'e'}, '@sophiebaber Wooh, someone cool is following me ']
# [{'first letter': 'n', 'last letter': 'e'}, 'might have some weird leg syndrome that does not let me run anymore ']
# [{'first letter': 'n', 'last letter': 'e'}, '@bonethuggirl your azz went to sleep to early big cuzzin  ....we coulda hit the CLUB ']
# [{'first letter': 'p', 'last letter': 'e'}, '@Sara_VFC haha who knows...ill think of something ']
# [{'first letter': 'p', 'last letter': 'e'}, '@Gerry_Butler you should have a vote and i vote yes!!!!! going on broadway would be amazing ']
# [{'first letter': 'n', 'last letter': 'e'}, 'angelus is the sex!!!!!  i wants to nibble on his arm hair!']
# [{'first letter': 'p', 'last letter': 'e'}, '@Brandelah O_O......-back away slowly while dialing 911 behind my back- OK ']
# [{'first letter': 'n', 'last letter': 'e'}, '@jimbofin Absolutely! ']
# [{'first letter': 'n', 'last letter': 'e'}, 'FUUUCCK i have over 100 pages to read for a class....aghhh and most of the time i have no clue whats happening when i do read for it. ']
# [{'first letter': 'n', 'last letter': 'e'}, 'Holy shit. That thunder actually woke me up! Also tired now ']
# [{'first letter': 'n', 'last letter': 'e'}, 'Back to work. What a joy. ']
# [{'first letter': 'n', 'last letter': 'e'}, 'I am unfollowing you until I get my #FullService on wednesday, spoilers make me sad  Going back to work, tweet ya layta!']
# [{'first letter': 'p', 'last letter': 'e'}, '@marycatherine07 im eatin lunch then ill be over gorgeous.  ha']
# [{'first letter': 'n', 'last letter': 'e'}, 'I think i made myself sick ']
# [{'first letter': 'n', 'last letter': 'e'}, 'is feeling like not going to school but he must go ']
# [{'first letter': 'p', 'last letter': 'e'}, '@JonathanRKnight for realz! Safe travels- hope things go much more smoothly this time around.   &amp; that you are having a great day so far!']
# [{'first letter': 'p', 'last letter': 'e'}, '@SandraPena is rockn the mic... chaaaaao ']
# [{'first letter': 'n', 'last letter': 'e'}, '@TherealRyu PS: caught the last of your broadcast. U ok? U seemed a little bit down. ']
# [{'first letter': 'p', 'last letter': 'e'}, "Oh i can't make you love me by bonnie raitt is speaking to my heart. "]
# [{'first letter': 'p', 'last letter': 'e'}, 'Tasmania Devil..Scary? Dangerous? Frightening?http://bit.ly/OgUeK  Ha,Ha  BOO !']
# [{'first letter': 'n', 'last letter': 'e'}, "@farraine123 yea I'm gonna give her some motrin  thanxx"]
# [{'first letter': 'n', 'last letter': 'e'}, '@89theBrainchild its not working ']
# [{'first letter': 'p', 'last letter': 'e'}, '@knauticus lol k goodnight ']
# [{'first letter': 'p', 'last letter': 'e'}, "thanks for all the support!!! messages coming from all over the world!! we're bigger than Big Brother now!!! "]
# [{'first letter': 'n', 'last letter': 'e'}, 'Oh last night was so amazing i want it back ']
# [{'first letter': 'n', 'last letter': 'e'}, 'I went to the beach and got a scalding  LOL']
# [{'first letter': 'n', 'last letter': 'e'}, '@MichelleCT moxies! Haha. Soo gay there  gaaah!']
# [{'first letter': 'p', 'last letter': 'e'}, 'needs to stop donating to every charity that asks for money. At least until my cash flow is under control. ']
# [{'first letter': 'p', 'last letter': 'e'}, 'sitting with Katie looking at different websites! ']
# [{'first letter': 'p', 'last letter': 'e'}, "@ReeshReesh8 ahhhh so you admit to the twitter addiction. That's a good start my traveling cousin. "]
# [{'first letter': 'n', 'last letter': 'e'}, 'I want to follow people ']
# [{'first letter': 'n', 'last letter': 'e'}, 'Feels like crap,ugh! Queezy stomach  back to work at 3']
# [{'first letter': 'n', 'last letter': 'e'}, 'Wow. Twitter is extremely boring at the moment. ']
# [{'first letter': 'n', 'last letter': 'e'}, '@DISCOxjunkie i wish i could do that, there are no little ids around my area ']
# [{'first letter': 'p', 'last letter': 'e'}, 'HEY WHAT IT DO!!  HAVE A GOOD DAY 2DAY...TWEET LATR....']
# [{'first letter': 'n', 'last letter': 'e'}, 'I miss my mommy...  I want her to be here, not in Costa Rica... D8']
# [{'first letter': 'p', 'last letter': 'e'}, 'Iz it me or has the net gotten more... how u say....... intriguing? lol ']
# [{'first letter': 'p', 'last letter': 'e'}, '@lmacvittie @dmacvittie Wireless will easily solve this problem ']
# [{'first letter': 'p', 'last letter': 'e'}, 'I am Re-Defining bbw = bold beautiful wonderful!! ']
# [{'first letter': 'p', 'last letter': 'e'}, "my sister is going to go on sims 3 for a bit, i'm going to go shower "]
# [{'first letter': 'n', 'last letter': 'e'}, 'is really bad at attempting to sleep alone.  insomina is a bitch + its too bright outside.']
# [{'first letter': 'n', 'last letter': 'e'}, 'on the way to Arbor Crest winery-not looking forward to this drive smashed by gear ']
# [{'first letter': 'p', 'last letter': 'e'}, 'good morning tweeps!, it will be a fine day today right? ']
# [{'first letter': 'n', 'last letter': 'e'}, "Omg. That's all I can say "]
# [{'first letter': 'n', 'last letter': 'e'}, "can't focus on homework, and has to go to work later tonight FUCK "]
# [{'first letter': 'p', 'last letter': 'e'}, '@biggfoot good to know..you are turning a good guy ']
# [{'first letter': 'n', 'last letter': 'e'}, 'i hate not working on sundays ']
# [{'first letter': 'n', 'last letter': 'e'}, 'is groggy. No more rain ']
# [{'first letter': 'p', 'last letter': 'e'}, '@tophatdog yeah i highlight it a bit . Thanks trish!  x']
# [{'first letter': 'p', 'last letter': 'e'}, 'At dinner with an amazing person i like to call Mom ']
# [{'first letter': 'p', 'last letter': 'e'}, '@drish29 haha yes sounds like a plan  ahhhh super excited!!!!']
# [{'first letter': 'p', 'last letter': 'e'}, "@TheAdamLambert hi adam!even if you are not the winner on american idol, you're still a winner for all of us! "]
# [{'first letter': 'n', 'last letter': 'e'}, 'Goin to work ']
# [{'first letter': 'n', 'last letter': 'e'}, '@laceyee I want Skype  I really wanted to video call!!!!!']
# [{'first letter': 'p', 'last letter': 'e'}, 'Mum gave me Mcdo gift certificates. Yeyeh happy eating to me. ']
# [{'first letter': 'p', 'last letter': 'e'}, '@muraliavarma plus facebook integration  #twitterfox #fail']
# [{'first letter': 'n', 'last letter': 'e'}, "@chriswiggin I had a french oral on 'The French Stereotype' this week. I wanted to get striking in but I didn't have enough time "]
# [{'first letter': 'p', 'last letter': 'e'}, 'Received my first ClickBank check yesterday from my http://VirialSignup.com sales...wooo hooo ']
# [{'first letter': 'p', 'last letter': 'e'}, 'Photo: My papaï¿½s 50th birthday celebration is not over yet.  The family and 30 of his closest relatives and... http://tumblr.com/xpk1p9kew']
# [{'first letter': 'p', 'last letter': 'e'}, 'My program works.  BAB mulai lancar lagi tanpa pencahar. Dan badan lebih kenceng. Tapi..nahan nafsu makannya gmn yah?']
# [{'first letter': 'n', 'last letter': 'e'}, 'I miss my darwin pants ']
# [{'first letter': 'n', 'last letter': 'e'}, "on my pillow. i'm soo sleeppyyy "]
# ...
# [{'first letter': 'n', 'last letter': 'e'}, 'has been neglecting @Twitter but is back on board! Altho im still getting stoopid security messages and no background images ']
# [{'first letter': 'p', 'last letter': 'e'}, '@ERisbayDSA lol....yeah...i think u would like some California sun now ']
# [{'first letter': 'p', 'last letter': 'e'}, 'JACOB GETS NAKKI =D yayyyy i love it so wanna see it  cant cant!!!!!']
# [{'first letter': 'n', 'last letter': 'e'}, 'Lost my ID, credit cards &amp; some dignity last night. ']
# [{'first letter': 'p', 'last letter': 'e'}, 'Perfect day for a perfect tan! ']
# [{'first letter': 'p', 'last letter': 'e'}, 'good night guys! woo so tired! ttyl! Take care and God Bless everyone! pray. ']
# [{'first letter': 'p', 'last letter': 'e'}, '@jonasbrothers AWESOME!!! I love you soo much guyys!!!  I cannot expect to see this video!']
# [{'first letter': 'n', 'last letter': 'e'}, '@AJWallace ah cheers. for civilsation, its sparta, olympics, theatre and what else? im so screwed - I have no notes ']
# [{'first letter': 'p', 'last letter': 'e'}, 'Ooh thats wat i can do this summer ']
# [{'first letter': 'n', 'last letter': 'e'}, "@timofuchs Me too  I've just used one of your shots on the owl. Ooh err!"]
# [{'first letter': 'n', 'last letter': 'e'}, 'eff work! freakin hella busy! ']
# [{'first letter': 'p', 'last letter': 'e'}, "5.18am!!!!!!! whhoops. i should be in bed, but i went to bed very early and now i can't sleep  haha."]
# [{'first letter': 'p', 'last letter': 'e'}, '@MelodyAdams I love the smell of gas too giiirl.  ahh, I could smell it allll day!']
# [{'first letter': 'p', 'last letter': 'e'}, '@lebox well, slightly more commercial here (*shocker*) ']
# [{'first letter': 'n', 'last letter': 'e'}, 'OFF ALL DAYS THE IMAC @ MY JOB HAD TO BE DOWN TODAYY SMH N ITUNES TAKIN MAD LONG TO INSTALL ON MY PC ']
# [{'first letter': 'p', 'last letter': 'e'}, 'Cartea din geanta are cont pe twitter: http://twitter.com/carteadingeanta ']
# [{'first letter': 'n', 'last letter': 'e'}, 'Day one of mwmt reunion is over  till tomorrow!']
# [{'first letter': 'p', 'last letter': 'e'}, "Two hours untill my mom gets home.  Maybe I'll actually get to drink something tomorrow! "]
# [{'first letter': 'p', 'last letter': 'e'}, 'I am in love with the new song All Time Low posted ']
# [{'first letter': 'n', 'last letter': 'e'}, "@tommcfly Horrible, I thought of you guys when I read it. Please be careful whenever it is you're coming home. "]
# [{'first letter': 'p', 'last letter': 'e'}, '@geminiriver I got a lot done. I anticipate reaching my goal tomorrow. ']
# [{'first letter': 'p', 'last letter': 'e'}, '@FollowLucas uhm, I love you? yes. very much so. ']
# [{'first letter': 'n', 'last letter': 'e'}, ' i wonder...']
# [{'first letter': 'n', 'last letter': 'e'}, "Some people call it child-ish, but this is my way of letting you know I'm done since I cant ever get myself to do it  in person...(yea u "]
# [{'first letter': 'n', 'last letter': 'e'}, 'going grocery shopping...wish i was shoe shopping  lol']
# [{'first letter': 'n', 'last letter': 'e'}, '#NAME?']
# [{'first letter': 'p', 'last letter': 'e'}, '@cotieno i think twitter is some kind of lucozade-juice for me. i get online each morning &amp; I am instantly zip zap zoom &amp; ready to go  ']
# [{'first letter': 'p', 'last letter': 'e'}, '@rod76 any time ']
# [{'first letter': 'p', 'last letter': 'e'}, '@hragv he plays the position of artist  we only have one triple base gallery']
# [{'first letter': 'n', 'last letter': 'e'}, '@littlebruh que triste heusaeusauhea ']
# [{'first letter': 'p', 'last letter': 'e'}, '@otherijustine oh yeah, 360s are very cool ']
# [{'first letter': 'p', 'last letter': 'e'}, 'going to have marche~  *big SMILES']
# [{'first letter': 'p', 'last letter': 'e'}, "@SagakureVK, thank you for all your hardwork! but please make sure that scanlations don't get clash with your RL stuff! we can wait! "]
# [{'first letter': 'n', 'last letter': 'e'}, 'brandon finished cleaning because i cant do anything right ']
# [{'first letter': 'n', 'last letter': 'e'}, '@MargretLuttrull that is just not right!!!!!!  Yes, I do wish that I had some ']
# [{'first letter': 'p', 'last letter': 'e'}, "Carlton 27 points up at quarter time! Collingwood hasn't kicked a goal!  #afl"]
# [{'first letter': 'p', 'last letter': 'e'}, "@ladygaga Haha awesome! I can't wait to see it "]
# [{'first letter': 'n', 'last letter': 'e'}, 'so sad to hear about Farrah Fawcett ']
# [{'first letter': 'p', 'last letter': 'e'}, "@tmill205 that's why I'm watching!! "]
# [{'first letter': 'p', 'last letter': 'e'}, 'http://twitpic.com/69eu7 - Mee &amp; Serena  (Me = Brown hair.)']
# [{'first letter': 'n', 'last letter': 'e'}, ' Wish the iPod had copy/paste']
# [{'first letter': 'p', 'last letter': 'e'}, 'off 2 bed nah.......Tryna change da future by livin n da present......I wonder wat happens next!!!!!!!!  Suprise me....Nite.Nite. ']
# [{'first letter': 'n', 'last letter': 'e'}, 'Ugh i am so sick  my ears are ringing insanely from last night too.']
# [{'first letter': 'p', 'last letter': 'e'}, '@BMolko hahah my mind went straigh to the gutter on that one!  Have a lovely semi....day off that is.... ']
# [{'first letter': 'n', 'last letter': 'e'}, 'http://twitpic.com/7yomz - But why take the cupholders? ']
# [{'first letter': 'n', 'last letter': 'e'}, "@DerekPineda you and @NRU23 are tweeter maniacs! I can't keep up even if I wanted to  lol"]
# [{'first letter': 'n', 'last letter': 'e'}, 'ahh!!! omgsh... there is arly big spiderr!!!! ']
# [{'first letter': 'n', 'last letter': 'e'}, 'At my house with @Megzakarockstar about to study some shit for school. Graduation on Monday ']
# [{'first letter': 'n', 'last letter': 'e'}, '@bombDUH Me either, i think he may be over me though!   im not doing anything though, just came from swimming missing HIM! ']
# [{'first letter': 'n', 'last letter': 'e'}, "I doubt I'm gonna make it to sleep tonight... Straight to the airport in approx. 2 1/2 hrs. "]
# [{'first letter': 'n', 'last letter': 'e'}, 'My fucking car got a punctured tire... And my dad thinks someone did it to me. ']
# [{'first letter': 'n', 'last letter': 'e'}, '@MrTeagan hope this passes .. no flu !!!  ']
# [{'first letter': 'n', 'last letter': 'e'}, 'ggrrrrr...spent zero time outside and I still gotta pack and get to Milwaukee.   I will do it quickly!!']
# [{'first letter': 'p', 'last letter': 'e'}, '@hanloosschilder yeah both ']
# [{'first letter': 'p', 'last letter': 'e'}, 'Gettin my anti-biotics for my throat. Then getting ice cream  thats the one good thing about being sick,  my mother spoils me ;)']
# [{'first letter': 'n', 'last letter': 'e'}, 'Its so sad... why do we have different timezones? ']
# [{'first letter': 'n', 'last letter': 'e'}, '@stephenfry  thats COOL all  need is a iphone now ']
# [{'first letter': 'n', 'last letter': 'e'}, '@chisaikame awe!  Why are you going?']
# [{'first letter': 'p', 'last letter': 'e'}, '@thekristenchaos Ya  i got to meet him. i got his autograph and my picture taken too. gosh he is adorable and very sweet']
# [{'first letter': 'p', 'last letter': 'e'}, 'thank GOD she didnt win!!  shell get loads of deals anyway...wanted diversity, aiden or sexy shaun to win! didnt care wich one!']
# [{'first letter': 'n', 'last letter': 'e'}, "So sad that TBS is over  but it was a fucking epic show! Adam makes me grin like a fool. :')"]
# [{'first letter': 'n', 'last letter': 'e'}, 'aint even been here for 5mins.. lmfao i need a nap. ']
# [{'first letter': 'n', 'last letter': 'e'}, 'volleyball hurts........... ']
# [{'first letter': 'p', 'last letter': 'e'}, '@dimsimkitty I can understand the pairing - I mean, absolutely - but I still just associate slash with genre, not procedurals!! ']
# [{'first letter': 'p', 'last letter': 'e'}, 'my tweeps, ima get sum sleep.. had an awesome nite. peace an love ']
# [{'first letter': 'p', 'last letter': 'e'}, '@LilCease hope your weekend is great! ']
# [{'first letter': 'n', 'last letter': 'e'}, '@kushAlabi thanks...finding them a proper shelter/agency is turning out to be an ordeal... ']
# [{'first letter': 'p', 'last letter': 'e'}, '@jesscorrie Love your fan video to the Jonas Brothers !  Please follow me! I am from Australia to!']
# [{'first letter': 'p', 'last letter': 'e'}, '@staciemwhite Its over for them ']
# [{'first letter': 'n', 'last letter': 'e'}, "Bad experience in ER... Life's really short. "]
# [{'first letter': 'p', 'last letter': 'e'}, 'Gotta love a short work day before I long holiday weekend! ']
# [{'first letter': 'n', 'last letter': 'e'}, 'the illness is advancing ']
# [{'first letter': 'n', 'last letter': 'e'}, 'is wanting to relax but gotta clean my house ']
# [{'first letter': 'n', 'last letter': 'e'}, "@itsMissATL nothing major it just didn't get straight enough "]
# [{'first letter': 'p', 'last letter': 'e'}, 'just had the BEST Thai food of my life!!  Totally taking Sam there when hes in Taipei ']
# [{'first letter': 'p', 'last letter': 'e'}, 'spending time with the sister and her roommate ']
# [{'first letter': 'p', 'last letter': 'e'}, "headin off home..sorry,no tweets frm me 2nyt...bt jst keep them coming, i'll read them 2mrw..good evening Manila..luv y'all "]
# [{'first letter': 'p', 'last letter': 'e'}, 'Getting ready to pack ']
# [{'first letter': 'p', 'last letter': 'e'}, "@sanjayguptaCNN Damn your p.s., was looking forward to Gupta's Jelly Bean Diet. "]
# [{'first letter': 'n', 'last letter': 'e'}, "@tinkermom Oh no!  (((HUGS))) I will send my prayers...I'm one of those believers."]
# [{'first letter': 'p', 'last letter': 'e'}, '@erica6185 wed. Is my only day ill see josh so were cleaning house. Weekend is insane... Next week I have tues. Sat. And sun. Ohhh jeez. ']
# [{'first letter': 'n', 'last letter': 'e'}, '@seattlestorm I am a season ticket owner but I scheduled a trip to Ohio the same time as the first game  any updates are appreciated']
# [{'first letter': 'n', 'last letter': 'e'}, 'Craving new ink so badly, its been too long ']
# [{'first letter': 'n', 'last letter': 'e'}, '@travln1 Oh noes! Give the little munchkin a hug for me ']
# [{'first letter': 'n', 'last letter': 'e'}, 'have to format my computer ']
# [{'first letter': 'n', 'last letter': 'e'}, 'Whats wrong with my internet connection!? ']
# [{'first letter': 'p', 'last letter': 'e'}, '@jojomad Egypt is for us rather close destination, something like Queensland for you ']
# [{'first letter': 'p', 'last letter': 'e'}, '@jordanknight Yay!!!  You have a picture again!!!  ']
# [{'first letter': 'p', 'last letter': 'e'}, '@CFOServices LOL!  I get right out of my heels and dress attire as soon as I hit the door. ']
# [{'first letter': 'p', 'last letter': 'e'}, "@purserj FFmpeg is great once it's setup "]
# [{'first letter': 'n', 'last letter': 'e'}, "The 14 year10 mth old kid rec'd a plaque, certif. &amp; LETTER for her tennis exploits. Problem is..she didn't tell us of party until after "]
# [{'first letter': 'n', 'last letter': 'e'}, ' i just want my trackball to get unstck. this is the onlÃ½ downside to blackberrys']
# [{'first letter': 'n', 'last letter': 'e'}, 'Braces hurt ']
# [{'first letter': 'n', 'last letter': 'e'}, 'I have to sing Dancing Through Life. ']
# [{'first letter': 'p', 'last letter': 'e'}, "@thestaciesutra Well worth a watch, I mean I think I had plenty of preconceptions, so it's very interesting to hear his take on it all. "]
# [{'first letter': 'n', 'last letter': 'e'}, "Just tell me if this is over because I will leave you alone. Please let me know because I'm just standing here, not knowing what to do. "]
# [{'first letter': 'n', 'last letter': 'e'}, "hungry....but i'm not allowed to eat outside food this enitre week....hmmmm what should i eat...i don't want cereal "]
# [{'first letter': 'n', 'last letter': 'e'}, 'got the twitter on the phone and laptop...lol service on the cell is weak @ da crib.... ']
# [{'first letter': 'p', 'last letter': 'e'}, "Played my first game on CB's new soccer team last night. Surprisingly not feeling as sore as I thought I would today. "]
# [{'first letter': 'n', 'last letter': 'e'}, "'the hangover' was pretty amusing! also, i got a mini captain kirk toy at wal-mart for $5. now i want a big one to go with my spock "]
# [{'first letter': 'p', 'last letter': 'e'}, 'Less than 2 hours ']
# [{'first letter': 'n', 'last letter': 'e'}, 'wishes she was in Ibiza where she belongs listening to Ferry Corsten in Amensia! ']
# [{'first letter': 'n', 'last letter': 'e'}, "relaxing! doing NO degree work! watching TV - wow, i'm finally a student and I'm leaving Loughborough 2moro! "]
# [{'first letter': 'n', 'last letter': 'e'}, '@TheCephas i mean.. i did get it but its bad reception so it actually didnt d/l  as far as ur sentence.. im not sure lol']
# [{'first letter': 'p', 'last letter': 'e'}, '@nardirv good night! ']
# [{'first letter': 'n', 'last letter': 'e'}, 'Health Food Sucks ']
# [{'first letter': 'p', 'last letter': 'e'}, 'And yes, still voting, just voted again. ']
# [{'first letter': 'n', 'last letter': 'e'}, "There's drama going around in twitter today ! Does anyone know why perez got hit ? Poor perez "]
# [{'first letter': 'n', 'last letter': 'e'}, "Ugh, I'm up at 2:30am because I'm coughing so hard I can't sleep "]
# [{'first letter': 'p', 'last letter': 'e'}, "&quot;How old are you?&quot; &quot;Twenty-Seven.&quot; &quot;I think it's ok that you aren't married yet.&quot;  Thanks for the unsolicited approval, 12-year old. "]
# [{'first letter': 'n', 'last letter': 'e'}, "@aspenglow i will be there as soon as I can after church tomorrow. do you have a truck? i'm sorry this has been such a horrific move "]
# [{'first letter': 'n', 'last letter': 'e'}, "@RdigitalPhoto ohhh...i'm sorry.  i'm such a procrastinator! lol. can we try it again?  pweeeeeze?"]
# [{'first letter': 'n', 'last letter': 'e'}, "laundry, it's not even mine   but tonight is one of the two gay dance events a month.... vt is so lame most of the time"]
# [{'first letter': 'n', 'last letter': 'e'}, 'is saying Lakers are the Champions to all you haters...... especially Boston fans ............ Start Work Tommorow ']
# [{'first letter': 'p', 'last letter': 'e'}, '@ToxicMelvin Last time I played Peggle it was NOT an RPG. ']
# [{'first letter': 'p', 'last letter': 'e'}, "@JRenee225 yea I'll have the mansion all decked out by that time. "]
# [{'first letter': 'n', 'last letter': 'e'}, '@Gilove2dance Awww, *hugs* I wish I could help. ']
# [{'first letter': 'p', 'last letter': 'e'}, "@edburns Nice, what's the deal with these bunnies ? "]
# [{'first letter': 'n', 'last letter': 'e'}, "Home with mom. She's in a lotta pain "]
# [{'first letter': 'p', 'last letter': 'e'}, "@pjdixon77 True. I don't think he knows what he's in for...  "]
# [{'first letter': 'n', 'last letter': 'e'}, 'mmmmm just ']
# [{'first letter': 'n', 'last letter': 'e'}, 'i wanna go and see shia and @realmfox at the transformers premiere today  but no tickets  ']
# [{'first letter': 'p', 'last letter': 'e'}, "nothing's more comforting than hearing grunge, especially on a rainy day  looovvee and happy!"]
# [{'first letter': 'p', 'last letter': 'e'}, "@funkcisco it's fun  I thought about u last night during McCartney."]
# [{'first letter': 'p', 'last letter': 'e'}, 'i have only one desire: to walk the cobbled streets alone. (( mgh. )) ']
# [{'first letter': 'p', 'last letter': 'e'}, "OK, I'm going to hype up one of the trending topics and say goodnight. "]
# [{'first letter': 'p', 'last letter': 'e'}, "HEY! if YOU are a #fitness tweeter &amp; NOT selling a SCAM weight loss product, follow me &amp; I'll follow you back for sure!! "]
# [{'first letter': 'p', 'last letter': 'e'}, "@h_ng you are my new shoe hero!  A woman after my own heart. &lt;3 shoes but don't &lt;3 paying full price, EVER! hahah."]
# [{'first letter': 'p', 'last letter': 'e'}, "Just got home from the ortho  cool colors ! Turquoise &amp; purple ? ;D i'd get yellow, but it's not a good color on teeth ;) Aha."]
# [{'first letter': 'n', 'last letter': 'e'}, 'I miss you ']
# [{'first letter': 'n', 'last letter': 'e'}, "Why can't I stay connected to the school internet while doing USMLEUS q's? WHY? "]

# %%
import csv
import nltk

def feature_extractor(word):
    first_l = word[0]
    last_l = word[-1]
    length = len(word) 
    d_feature = {"first letter" : first_l,"last letter" : last_l,"length": length}
    return d_feature
    
def featureset():
    """creates the data set for training"""
    SENTIMENT_CSV=r"/Users/sheva/Downloads/TweetSentiment (1).csv"
    with open(SENTIMENT_CSV, 'rt', encoding='utf-8') as sobj:
        sdata=csv.reader(sobj)
        featureset=list()
        for row in sdata:
            features=feature_extractor(row[1])
            featureset.append([features,row[0]])
    return featureset

def ML_Train():
    """Train an NB model"""
    fset=featureset()
    train_set=fset[:4000]
    test_set=fset[4000:]
    
ML_Train()
nb_classifier=ML_Train()
i_sentence=input("please enter a sentence: ").lower()
i_features=feature_extractor(i_sentence)
sentiment=nb_classifier.classify(i_features)
print("Sentiment of the word: ", sentiment)
# Out:
# please enter a sentence: sheva
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/n6/9xn1m47d4j14dpz1gtcsx0wh0000gn/T/ipykernel_23443/746859125.py in <module>
#      30 i_sentence=input("please enter a sentence: ").lower()
#      31 i_features=feature_extractor(i_sentence)
# ---> 32 sentiment=nb_classifier.classify(i_features)
#      33 print("Sentiment of the word: ", sentiment)
#
# AttributeError: 'NoneType' object has no attribute 'classify'

# %% [markdown]
# ### Step 2: Train the model on the training data set
# ##### Split the sample to training and testing data set
#
# We will split the feature data set into training and test data sets. The training set is used to train our ML model and then the testing set can be used to check how good the model is. It is normal to use 20% of the data set for testing purposes. In our case we will retain 2000 words for training and the rest for testing.
#
# ##### Use ML method (Naive Bayes) to create the classifier model
#
# The NLTK module gives us several ML methods to create a classifier model using our training set and based on our selected features.

# %% [markdown]
# #### Figure 3: Training
#
#
# <center>
#     <img src="Tr2.png"  width="500" title="Training">
# </center>

# %%
import csv
import nltk # this module has NaiveBayes classifier model

def feature_extractor(word):
    """ This is my feature extractor. Givern a word, it returns a dictonary of the first and last letter
    of the word given to it"""
    first_l = word[0]
    last_l = word[-1]
    dict_feature = {"first letter" : first_l,"last letter" : last_l}
    return dict_feature

def gen_featureset():
    """ This function creates a feature set for the word_sentiment.csv file"""
    SENTIMENT_CSV = r"C:\Users\pmedappa\Dropbox\Tilburg\Course 2020-2021\DSS\Lab 2\Sentiments\word_sentiment.csv"
    with open(SENTIMENT_CSV,'rt', encoding='utf-8') as csvobj:
        ws_data = csv.reader(csvobj)
        featureset = list()
        for row in ws_data:
            w_feature = list()
            feature = feature_extractor(row[0])
            w_feature.append(feature)
            w_feature.append(row[1])
            featureset.append(w_feature)
        return featureset
            

def ML_train():
    """ This will train the classifier using the word sentiment feature set"""
    featureset = gen_featureset()
    # split the feature set into training and testing sets
    train_set = featureset[:2000]
    test_set = featureset[2000:]
    classifier = nltk.NaiveBayesClassifier.train(train_set) #Train the NaiveBayes model using the training data set
    return classifier

nb_classifier = ML_train()
print(nb_classifier)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/n6/9xn1m47d4j14dpz1gtcsx0wh0000gn/T/ipykernel_23167/2064703032.py in <module>
#      34     return classifier
#      35
# ---> 36 nb_classifier = ML_train()
#      37 print(nb_classifier)
#
# /var/folders/n6/9xn1m47d4j14dpz1gtcsx0wh0000gn/T/ipykernel_23167/2064703032.py in ML_train()
#      27 def ML_train():
#      28     """ This will train the classifier using the word sentiment feature set"""
# ---> 29     featureset = gen_featureset()
#      30     # split the feature set into training and testing sets
#      31     train_set = featureset[:2000]
#
# /var/folders/n6/9xn1m47d4j14dpz1gtcsx0wh0000gn/T/ipykernel_23167/2064703032.py in gen_featureset()
#      13     """ This function creates a feature set for the word_sentiment.csv file"""
#      14     SENTIMENT_CSV = r"C:\Users\pmedappa\Dropbox\Tilburg\Course 2020-2021\DSS\Lab 2\Sentiments\word_sentiment.csv"
# ---> 15     with open(SENTIMENT_CSV,'rt', encoding='utf-8') as csvobj:
#      16         ws_data = csv.reader(csvobj)
#      17         featureset = list()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\pmedappa\\Dropbox\\Tilburg\\Course 2020-2021\\DSS\\Lab 2\\Sentiments\\word_sentiment.csv'

# %% [markdown]
# ### Step 3: Using the classifier object created predict the sentiment of a given word

# %% [markdown]
# #### Figure 4: Prediction
#
#
# <center>
#     <img src="Pr.png"  width="500" title="Prediction">
# </center>

# %%
import csv
import nltk

def feature_extractor(word):
    """ This is my feature extractor. Givern a word, it returns a dictonary of the first and last letter
    of the word given to it"""
    first_l = word[0]
    last_l = word[-1]
    dict_feature = {"first letter" : first_l,"last letter" : last_l}
    return dict_feature

def gen_featureset():
    """ This function creates a feature set for the word_sentiment.csv file"""
    SENTIMENT_CSV = r"C:\Users\pmedappa\Dropbox\Tilburg\Course 2020-2021\DSS\Lab 2\Sentiments\word_sentiment.csv"
    with open(SENTIMENT_CSV,'rt', encoding='utf-8') as csvobj:
        ws_data = csv.reader(csvobj)
        featureset = list()
        for row in ws_data:
            w_feature = list()
            feature = feature_extractor(row[0])
            w_feature.append(feature)
            w_feature.append(row[1])
            featureset.append(w_feature)
        return featureset
            

def ML_train():
    """ This will train the classifier using the word sentiment feature set"""
    featureset = gen_featureset()
    train_set = featureset[:2000]
    test_set = featureset[2000:]
    classifier = nltk.NaiveBayesClassifier.train(train_set)
    return classifier

i_word = input("Enter a word : ").lower()
nb_classifier = ML_train()
i_features = feature_extractor(i_word) # extract the features of the input word
sentiment = nb_classifier.classify(i_features) # use the nb classifier to find the sentiment of the input word
print("Sentiment of the word : ", sentiment)
# Out:
# Enter a word : good
# Sentiment of the word :  -2

# %% [markdown]
# ### Step 4: Evaluating the model
#
# Find how good the model is in identifying the labels. Ensure that the test set is distinct from the training corpus. If we simply re-used the training set as the test set, then a model that simply memorized its input, without learning how to generalize to new examples, would receive misleadingly high scores. The function nltk.classify.accuracy() will calculate the accuracy of a classifier model on a given test set.

# %% [markdown]
# #### Figure 5: Evaluation
#
#
# <center>
#     <img src="Ev.png"  width="500" title="Evaluation">
# </center>

# %%
import csv
import nltk
import random

def feature_extractor(word):
    """ This is my feature extractor. Givern a word, it returns a dictonary of the first and last letter
    of the word given to it"""
    first_l = word[0]
    last_l = word[-1]
    dict_feature = {"first letter" : first_l,"last letter" : last_l}
    return dict_feature

def gen_featureset():
    """ This function creates a feature set for the word_sentiment.csv file"""
    SENTIMENT_CSV = r"C:\Users\pmedappa\Dropbox\Tilburg\Course 2020-2021\DSS\Lab 2\Sentiments\word_sentiment.csv"
    with open(SENTIMENT_CSV,'rt', encoding='utf-8') as csvobj:
        ws_data = csv.reader(csvobj)
        featureset = list()
        for row in ws_data:
            w_feature = list()
            feature = feature_extractor(row[0])
            w_feature.append(feature)
            if int(row[1]) >= 0: #Club the sentiment value into positive and negative (two labels)
                sentiment = 'positive'
            else: sentiment = 'negative'
            w_feature.append(sentiment)
            featureset.append(w_feature)
        return featureset
            

def ML_train():
    """ This will train the classifier using the word sentiment feature set"""
    featureset = gen_featureset()
    random.shuffle(featureset) # !! IT IS IMPORTANT TO SHUFFLE THE LABELLED DATA SINCE THE WORDS ARE ALPHABETICAL
    train_set = featureset[:2000]
    test_set = featureset[2000:]
    classifier = nltk.NaiveBayesClassifier.train(train_set)
    acc = nltk.classify.accuracy(classifier,test_set) #Find accuracy of the model using the test set
    print("The accuracy of the model is ", acc)
    classifier.show_most_informative_features() #show the most informative features
    return classifier

i_word = input("Enter a word : ").lower()
nb_classifier = ML_train()
i_features = feature_extractor(i_word)
print("Features extracted from the word : ",i_features)
sentiment = nb_classifier.classify(i_features)
print("Sentiment of the word : ", sentiment)

# %% [markdown]
# ##### NOTE: Improvements made to increase accuracy
# - Shuffle the corpus so that the issue of alphebetic ordering of the word is overcome
# - Reduce variance in outcome by clubbing it (i.e. change the range of sentiment from -5 to 5 .. to 'posiitve' and 'negative')

# %% [markdown]
# ### Excercise 1
#
# *Improve the feature extractor (by adding new features) so that the test accuracy goes up by a bit. Can you reach 70% accuracy?.*

# %%
#Enter code here
import csv
import nltk
import random

def feature_extractor(word):
    """ This is my feature extractor. Givern a word, it returns a dictonary of the first and last letter
    of the word given to it"""
    first_l = word[0]
    last_l = word[-1]
    first2_l = word[0:2]
    last2_l = word[-2:]
    l = len(word)
    dict_feature = {"first 2 letters" : first2_l,"last 2 letters" : last2_l,
                    "first letter" : first_l,"last letter" : last_l,
                    "length" : l}
    return dict_feature

def gen_featureset():
    """ This function creates a feature set for the word_sentiment.csv file"""
    SENTIMENT_CSV = "C:/Users/pmedappa/Dropbox/Tilburg/Course 2019-2020/DSS/Lab4/Sentiments/word_sentiment.csv"
    with open(SENTIMENT_CSV,'rt', encoding='utf-8') as csvobj:
        ws_data = csv.reader(csvobj)
        featureset = list()
        for row in ws_data:
            w_feature = list()
            feature = feature_extractor(row[0])
            w_feature.append(feature)
            if int(row[1]) > 0:
                sentiment = "positive"
            else: sentiment = "negative"
            w_feature.append(sentiment)
            featureset.append(w_feature)
        return featureset
            

def ML_train():
    """ This will train the classifier using the word sentiment feature set"""
    featureset = gen_featureset()
    random.shuffle(featureset)
    train_set = featureset[:2000]
    test_set = featureset[2000:]
    classifier = nltk.NaiveBayesClassifier.train(train_set)
    acc = nltk.classify.accuracy(classifier,test_set)
    print("The accuracy of the model is ", acc)
    classifier.show_most_informative_features()
    return classifier

i_word = input("Enter a word : ").lower()
nb_classifier = ML_train()
i_features = feature_extractor(i_word)
print("Features extracted from the word : ",i_features)
sentiment = nb_classifier.classify(i_features)
print("Sentiment of the word : ", sentiment)

# %% [markdown]
# ### Excercise 2
#
# Build a classifier model that can predict the sentiment of the sentence. Please use the TweetSentiment.csv file provided for training and testing. This file has a list of 5000 tweets ranked on the basis of their sentiment (positive and negative).

# %%
 # discussed in lab 4
    
import csv
import nltk
import random

def feature_extractor(sentence):
    l_sentence = sentence.split()
    f_word = l_sentence[0]
    l_word = l_sentence[-1]
    length = len(l_sentence) 
    
    if length >= 2:
        f2_word = l_sentence[0]+" "+l_sentence[1]
        l2_word = l_sentence[-2]+" "+l_sentence[-1]
    else:
        f2_word = ""
        l2_word = ""
    d_feature = {"first word" : f_word,"last word" : l_word,"length": length, "first two words": f2_word, "last 2 words": l2_word}
    return d_feature
    
def featureset():
    """creates the data set for training"""
    SENTIMENT_CSV=r"/Users/sheva/Downloads/TweetSentiment (1).csv"
    with open(SENTIMENT_CSV, 'rt', encoding='utf-8') as sobj:
        sdata=csv.reader(sobj)
        featureset=list()
        for row in sdata:
            features=feature_extractor(row[1])
            featureset.append([features,row[0]])
    return featureset

def ML_Train():
    """Train an NB model"""
    fset=featureset()
    random.shuffle(fset)
    train_set=fset[:4000]
    test_set=fset[4000:]
    classifier = nltk.NaiveBayesClassifier.train(train_set) #Train the NaiveBayes model using the training data set
    acc = nltk.classify.accuracy(classifier, test_set)
    print("the accuracy of the NB model is ", acc)
    classifier.show_most_informative_features()
    
    dt_classifier = nltk.DecisionTreeClassifier.train(train_set)
    acc = nltk.classify.accuracy(classifier, test_set)
    print("the accuracy of the DT model is ", acc)
    classifier.show_most_informative_features()
    
    return classifier

    
ML_Train()
nb_classifier=ML_Train()
i_sentence=input("please enter a sentence: ").lower()
i_features=feature_extractor(i_sentence)
sentiment=nb_classifier.classify(i_features)
print("Sentiment of the word: ", sentiment)
# Out:
# the accuracy of the NB model is  0.589
# Most Informative Features
#                last word = 'fun'          positi : negati =      7.0 : 1.0
#                   length = 29             negati : positi =      5.8 : 1.0
#               first word = 'getting'      positi : negati =      5.0 : 1.0
#               first word = 'watching'     positi : negati =      5.0 : 1.0
#                last word = 'go'           negati : positi =      5.0 : 1.0
#                last word = 'thanks'       positi : negati =      5.0 : 1.0
#                last word = 'today.'       negati : positi =      5.0 : 1.0
#          first two words = 'I miss'       negati : positi =      5.0 : 1.0
#          first two words = "I don't"      negati : positi =      4.3 : 1.0
#                last word = 'haha'         positi : negati =      4.3 : 1.0
# the accuracy of the DT model is  0.589
# Most Informative Features
#                last word = 'fun'          positi : negati =      7.0 : 1.0
#                   length = 29             negati : positi =      5.8 : 1.0
#               first word = 'getting'      positi : negati =      5.0 : 1.0
#               first word = 'watching'     positi : negati =      5.0 : 1.0
#                last word = 'go'           negati : positi =      5.0 : 1.0
#                last word = 'thanks'       positi : negati =      5.0 : 1.0
#                last word = 'today.'       negati : positi =      5.0 : 1.0
#          first two words = 'I miss'       negati : positi =      5.0 : 1.0
#          first two words = "I don't"      negati : positi =      4.3 : 1.0
#                last word = 'haha'         positi : negati =      4.3 : 1.0
# the accuracy of the NB model is  0.574
# Most Informative Features
#               first word = 'So'           negati : positi =      6.3 : 1.0
#               first word = 'This'         negati : positi =      6.3 : 1.0
#          first two words = 'I have'       negati : positi =      5.6 : 1.0
#          first two words = 'I miss'       negati : positi =      5.6 : 1.0
#                last word = 'again'        negati : positi =      5.6 : 1.0
#                last word = ';)'           positi : negati =      5.0 : 1.0
#               first word = 'Its'          negati : positi =      5.0 : 1.0
#                last word = 'bad'          negati : positi =      5.0 : 1.0
#                last word = 'go'           negati : positi =      5.0 : 1.0
#                last word = 'sleep'        negati : positi =      5.0 : 1.0
# the accuracy of the DT model is  0.574
# Most Informative Features
#               first word = 'So'           negati : positi =      6.3 : 1.0
#               first word = 'This'         negati : positi =      6.3 : 1.0
#          first two words = 'I have'       negati : positi =      5.6 : 1.0
#          first two words = 'I miss'       negati : positi =      5.6 : 1.0
#                last word = 'again'        negati : positi =      5.6 : 1.0
#                last word = ';)'           positi : negati =      5.0 : 1.0
#               first word = 'Its'          negati : positi =      5.0 : 1.0
#                last word = 'bad'          negati : positi =      5.0 : 1.0
#                last word = 'go'           negati : positi =      5.0 : 1.0
#                last word = 'sleep'        negati : positi =      5.0 : 1.0

# %% [markdown]
# #### Note: Development testing and error analysis
#
# Using a seperate dev-test set, we can generate a list of the errors that the classifier makes when predicting the sentiment. We can then examine individual error cases where the model predicted the wrong label, and try to determine what additional pieces of information would allow it to make the right decision (or which existing pieces of information are tricking it into making the wrong decision). The feature set can then be adjusted accordingly.

# %%
### assignment

import panda as pd

new_tweet_csv = r"Trump_Tweets_2019.csv"
index_csv = r"nasdaq"
memrge_csv = r"merged_trump_nasdaq"





##2nd part of the assignment
import nltk
nltk.download('stopwords')

#

import nltk
import random
import csv

def tokenize(sentence):
    """this function does the task of converting a sentence into a list of words"""
    t_words = sentence.split()
    return t_words

def removestopwords():
    stop_words=set(stepwords.words("english"))
    filtered_tokens=list()
    for w in tokens:
        if w not in stop_words:
            filtered_tokens.append(w.lower())        
    return filtered_tokens


def mostfreq_words(all_tokenwords):
    all_words=nltk.FreqDist(all_tokenwords)
    word_features=list(all_words)[:5000]
    return word_features
    

merge_csv = r"merged_tweet_NASDAQ_2019"
with open (merge_csv, 'rt', encoding='utf-8') as tweetobj:
    classified_tweet=csv.reader(tweetobj)
    for tweet in classified_tweet
    tokens = tokenize(tweet[2])
    print(tokens)
    
    filtered_tokens = removestopwords(tokens)
    print(filtered_tokens)
